# %% [markdown]
# ## Case study  - Football Data Analysis
#
# We have the football data of a popular premier league which asseses the differnet qualities in a football player. We need to grill this data and report the important findings from the grilling and drilling exercise. We are also supposed to derive useful insights about the whole dataset.

# %%
# Import the libraries 
import numpy as np
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt  # seaborn is based on matplotlib
sns.set(color_codes=True) # adds a nice background to the graphs
# %matplotlib inline 
# tells python to actually display the graphs

# %% [markdown]
# ### <a id = "link1"></a>Overview of the data

# %%
# Read the Data 
df = pd.read_excel('Football Players.xlsx')

# %%
# View first 3 rows of data 
df.head(3)
# Out:
#    Wage ($)    Value ($)               Name   Age  \
# 0  491304.0   83043478.0  Cristiano Ronaldo  32.0
# 1  491304.0   91304348.0           L. Messi  30.0
# 2  243478.0  106956522.0             Neymar  25.0
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png     94.0       94.0
# 1  https://cdn.sofifa.org/flags/52.png     93.0       93.0
# 2  https://cdn.sofifa.org/flags/54.png     92.0       94.0
#
#                   Club  ... Short passing  Shot power  Sliding tackle  \
# 0       Real Madrid CF  ...          83.0        94.0            23.0
# 1         FC Barcelona  ...          88.0        85.0            26.0
# ...

# %%
# understand shape and size of data from 
print(df.shape)
print(df.size)
# Out:
# (17981, 46)
# 827126

# %%
df.info()
print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 46 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Wage ($)             17981 non-null  float64
#  1   Value ($)            17981 non-null  float64
#  2   Name                 17981 non-null  object
#  3   Age                  17981 non-null  float64
#  4   Photo                17981 non-null  object
#  5   Nationality          17981 non-null  object
#  6   Flag                 17981 non-null  object
#  7   Overall              17981 non-null  float64
#  8   Potential            17981 non-null  float64
#  9   Club                 17733 non-null  object
#  10  Club Logo            17981 non-null  object
#  11  Acceleration         17897 non-null  float64
#  12  Aggression           17913 non-null  float64
#  13  Agility              17910 non-null  float64
#  14  Balance              17924 non-null  float64
# ...

# %%
# Conditions within dataframe 
pd=df[df['Sprint speed'] > 70]
pd.sortby(ascending= False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 3>()
#       1 # Conditions within dataframe
#       2 pd=df[df['Sprint speed'] > 70]
# ----> 3 pd.sortby(ascending= False)
#
# File F:\ana\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sortby'

# %%
#Unique football positions
df['Preferred Positions'].unique()
# Out:
# array(['ST LW', 'RW', 'LW', 'ST', 'GK', 'CDM CM', 'CB', 'RM CM CAM',
#        'RM LW ST LM', 'ST CAM', 'LW RW ST', 'CDM CAM CM', 'RW CAM',
#        'RW RM', 'CM CDM', 'LM RM CAM', 'LB', 'CM', 'LM CM CAM', 'LM CM',
#        'LM RM CAM CM', 'CM CB LB', 'LM LB', 'ST CAM RW CF', 'CAM LW',
#        'LW ST LM', 'CAM CM', 'CDM CB', 'ST LW CF', 'CAM CDM CM', 'LW LM',
#        'RM LM', 'CDM', 'LM RW RM', 'LB RB CB', 'LW RW', 'LW LM RM CAM',
#        'RM', 'LM CF CAM', 'RB', 'LM CAM LW', 'LM RM CM', 'CAM LM',
#        'CAM RM RW', 'RM CAM', 'CAM LW RW', 'LM', 'LM CAM', 'CAM CF ST',
#        'CM CB CDM', 'RW ST', 'RW LW CM', 'CF CAM', 'LW CM', 'RWB RB',
#        'CAM', 'ST CF', 'LM ST', 'CM CAM', 'CF ST', 'CB RB', 'CF CM CAM',
#        'LM CAM RW LW', 'LM RM', 'LM RW LW', 'LM CF RM', 'CAM LW CM',
#        'ST LM', 'LM ST RM', 'RM RW', 'RM CM', 'RB CB', 'CM RW RB',
#        'LM RM RW', 'RW LW', 'CM CDM CB', 'LB CB', 'ST RM LM', 'CAM LM CM',
# ...

# %%
#Total ST
df[df['Preferred Positions']=='ST']
# Out:
#        Wage ($)   Value ($)            Name   Age  \
# 3      443478.0  84347826.0       L. Suárez  30.0
# 5      308696.0  80000000.0  R. Lewandowski  28.0
# 9      239130.0  66956522.0      G. Higuaín  29.0
# 16     282609.0  57826087.0       S. Agüero  29.0
# 23     143478.0  53043478.0   P. Aubameyang  28.0
# ...         ...         ...             ...   ...
# 17885     870.0     43478.0    S. McSweeney  19.0
# 17944    1739.0     52174.0          M. Foy  18.0
# 17948     870.0     60870.0       R. Roache  17.0
# 17969     870.0     52174.0      F. Prohart  18.0
# 17978     870.0     52174.0        J. Young  17.0
#
#                                                  Photo          Nationality  \
# 3      https://cdn.sofifa.org/48/18/players/176580.png              Uruguay
# 5      https://cdn.sofifa.org/48/18/players/188545.png               Poland
# 9      https://cdn.sofifa.org/48/18/players/167664.png            Argentina
# ...

# %%
pd=df.groupby('Nationality').size().sort_values(ascending = False)
sns.set({'figure.figsize': (8,6)})
sns.histplot(df['Nationality'], kde=True);

# %%
#Total players in their respective age gp
age_under20=df[df['Age']<=25]
age_25to30=df[(df['Age']>25)&(df['Age']<30)]
age_above30=df[df['Age']>=30]
var=np.array([age_under20['Name'].count(),age_25to30['Name'].count(),age_above30['Name'].count()])
label=["<=25",">25 & <30",">=30"]
plt.title("Total players in their respective age gp")
plt.pie(x=var,labels=label,autopct="%.2f%%")
plt.show()

# %%
#TOTAL NO OF NATIONS
df['Nationality'].nunique()
# Out:
# 165

# %%
df['Preferred Positions'].value_counts().head(10)
# Out:
# CB        2216
# GK        2029
# ST        1847
# CM         759
# LB         746
# CM CDM     644
# RB         637
# CDM CM     549
# CDM        423
# CAM        320
# Name: Preferred Positions, dtype: int64

# %%
sns.jointplot(df['Standing tackle'],df['Sliding tackle'], kind="hex");
# Out:
# F:\ana\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Most Valuable club
k1=df.groupby('Club')['Value ($)'].sum().sort_values(ascending=False)
# Out:
# Club
# Real Madrid CF         718869567.0
# FC Bayern Munich       651152174.0
# FC Barcelona           647391306.0
# Chelsea                585291305.0
# Paris Saint-Germain    549347829.0
#                           ...
# Finn Harps               2582607.0
# Galway United            2469565.0
# Drogheda United          2217392.0
# Limerick FC              2139131.0
# Bray Wanderers           2060872.0
# Name: Value ($), Length: 647, dtype: float64

# %% [markdown]
# **Real Madrid CF is the most valuable team in the world with a squad of worth 7.18 billion U.S.D**

# %%
#Highest paying club
df.groupby('Club')['Wage ($)'].sum().sort_values(ascending=False)
# Out:
# Club
# FC Barcelona         4166958.0
# Real Madrid CF       4131302.0
# Manchester United    3176521.0
# Chelsea              3075651.0
# FC Bayern Munich     2846087.0
#                        ...
# Würzburger FV          20010.0
# Cork City              20010.0
# Limerick FC            20009.0
# VfR Aalen              18270.0
# Bray Wanderers         18270.0
# Name: Wage ($), Length: 647, dtype: float64

# %% [markdown]
# **FC Barcelona are the Premier leagues's highest paying club, spending around 4 million U.S.D**
